# %% [markdown]
# # Load Final Detuned GPG Pulses
#
# This notebook inspects the curated 5-parameter detuned GPG pulse data used for the paper figure.

# %%
from pathlib import Path
import pandas as pd

repo_root = Path.cwd().resolve()
if not (repo_root / "datas" / "final_gpg_pulses").exists():
    repo_root = repo_root.parent

data_dir = repo_root / "datas" / "final_gpg_pulses"
manifest = pd.read_csv(data_dir / "manifest.csv")
all_pulses = pd.read_csv(data_dir / "all_pulses.csv")
metrics = pd.read_csv(data_dir / "best_metrics.csv")

# %%
pulse_columns = ["alpha", "beta", "gamma", "kappa", "detuning"]

print(f"Per-target sequence files: {len(manifest)}")
print(f"Flattened pulse rows: {len(all_pulses)}")
print(f"Selected (p, C) metric rows: {len(metrics)}")
print(f"Pulse columns present: {pulse_columns == [c for c in pulse_columns if c in all_pulses.columns]}")

metrics[["p", "GPG cooperativity", "GPG infidelity", "max state-prep infidelity"]]
# Out:
# Per-target sequence files: 275
# Flattened pulse rows: 2508
# Selected (p, C) metric rows: 10
# Pulse columns present: True
#         p  GPG cooperativity  GPG infidelity  max state-prep infidelity
# 0  0.0005       1.000000e+06        0.001817                   0.136017
# 1  0.0005       1.000000e+07        0.000197                   0.047298
# 2  0.0005       1.000000e+08        0.000014                   0.014276
# 3  0.0005       1.000000e+09        0.000008                   0.004656
# 4  0.0005       1.000000e+10        0.000002                   0.001703
# 5  0.0010       1.000000e+06        0.001805                   0.148250
# 6  0.0010       1.000000e+07        0.000351                   0.050113
# 7  0.0010       1.000000e+08        0.000045                   0.016171
# 8  0.0010       1.000000e+09        0.000020                   0.005149
# 9  0.0010       1.000000e+10        0.000005                   0.002070

# %%
first = manifest.iloc[0]
sequence_path = data_dir / first["file"]
sequence = pd.read_csv(sequence_path)

print(sequence_path.relative_to(repo_root))
sequence.head()
# Out:
# datas/final_gpg_pulses/sequences/p_5p000000000000em04__C_1p000e06__feedback_u_0__eig_00.csv
#    pulse_index     alpha      beta     gamma     kappa  detuning
# 0            1  0.757153 -0.606559  3.005626 -2.465312  0.050000
# 1            2 -0.143053  1.300860 -3.134455 -1.782926  0.319787
# 2            3  0.937243 -2.766657  2.775673 -0.330280  1.015174
# 3            4  0.275724  1.437332  0.378311  1.432599  0.569366
# 4            5  0.368194  0.772114  0.468558 -2.871495  1.688519

# %% [markdown]
# Each sequence row contains one pulse index and the five detuned GPG parameters `alpha`, `beta`, `gamma`, `kappa`, and `detuning`.
